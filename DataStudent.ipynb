# %% [markdown]
# ##Data Student
#
# ##https://github.com/aksalnvnza/KecerdasanBuatan.git

# %%
students = [
    {
        "nim": 2046363636,
        "nama": "Iwan",
        "semester": 6,
        "hasil": [
            {
                "mata_kuliah": "kecerdasan buatan",
                "hadir": 18,
                "sks": 3,
                "nilai":{
                    "tugas": 75,
                    "uts": 80,
                    "uas": 77
                }
            },
            {
                "mata_kuliah": "basis data 1",
                "hadir": 20,
                "sks": 3,
                "nilai":{
                    "tugas": 80,
                    "uts": 82,
                    "uas": 67
                }
            },
            {
                "mata_kuliah": "digital enterpreneur",
                "hadir": 14,
                "sks": 2,
                "nilai":{
                    "tugas": 90,
                    "uts": 82,
                    "uas": 80
                }
            }
            ]
            },
        {
        "nim": 2046363777,
        "nama": "Saepulloh",
        "semester": 2,
        "hasil": [
            {
                "mata_kuliah": "algoritma & pemrogaman 1",
                "hadir": 20,
                "sks": 3,
                "nilai":{
                    "tugas": 90,
                    "uts": 80,
                    "uas": 70
                }
            },
            {
                "mata_kuliah": "kalkulus 1",
                "hadir": 21,
                "sks": 3,
                "nilai":{
                    "tugas": 70,
                    "uts": 60,
                    "uas": 67,
                }
            },
            {
                "mata_kuliah": "statistika dan probabilitas",
                "hadir": 13,
                "sks": 2,
                "nilai":{
                    "tugas": 90,
                    "uts": 70,
                    "uas": 88
                }
            }
                ]
            },
    {
        "nim": 2046363790,
        "nama": "Sholihin",
        "semester": 8,
        "hasil": [
            {
                "mata_kuliah": "Sistem Penunjang Keputusan",
                "hadir": 19,
                "sks": 3,
                "nilai":{
                    "tugas": 80,
                    "uts": 90,
                    "uas": 65
                }
            },
            {
                "mata_kuliah": "Rekayasa Perangkat Lunak",
                "hadir": 21,
                "sks": 3,
                "nilai":{
                    "tugas": 70,
                    "uts": 80,
                    "uas": 77,
                }
            },
            {
                "mata_kuliah": "Etika Profesi",
                "hadir": 14,
                "sks": 2,
                "nilai":{
                    "tugas": 90,
                    "uts": 80,
                    "uas": 88
                }
            }
                ]
            } 
        ]

# %%
# expected result
results = [
    {
    "nim": "",
    "nama": "",
    "rangkuman_nilai":[
        {
            "mata_kuliah": "",
            "nilai": " : 0 - 100",
            "Grade": ": A | B | C | D | E"
        },	
        {
            "mata_kuliah": "",
            "nilai": " : 0 - 100",
            "Grade": ": A | B | C | D | E"
        }
        ]},
    {
        "nim": "",
        "nama": "",
        "rangkuman_nilai":[
        {
            "mata_kuliah": "",
            "nilai": " : 0 - 100",
            "Grade": ": A | B | C | D | E"
        },
        {
            "mata_kuliah": "",
            "nilai": " : 0 - 100",
            "Grade": ": A | B | C | D | E"
        }
    ]},
]

# %%
# extract data Sholihin
nim = students[2]["nim"]
nama = students[2]["nama"]
print("nim:", nim)
print("nama:", nama)
# nilai sistem penunjang keputusan
students[2]["hasil"][0]
nama_mk = students[2]["hasil"][0]["mata_kuliah"]
hadir = students[2]["hasil"][0]["hadir"]
sks = students[2]["hasil"][0]["sks"]
print("Mata Kuliah:", nama_mk)
print("Sks:", sks)
print("Kehadiran:", hadir)

tugas = students[2]["hasil"][0]["nilai"]["tugas"]
uts = students[2]["hasil"][0]["nilai"]["uts"]
uas = students[2]["hasil"][0]["nilai"]["uas"]
print("tugas:", tugas)
print("UTS:", uts)
print("UAS:", uas)
# Out:
# nim: 2046363790
# nama: Sholihin
# Mata Kuliah: Sistem Penunjang Keputusan
# Sks: 3
# Kehadiran: 19
# tugas: 80
# UTS: 90
# UAS: 65

# %%
# get all data
for student in students:
    nim = student["nim"]
    nama = student["nama"]
    print("nim:", nim)
    print("nama:", nama)
    for mk in student["hasil"]:
        print("..............................")
        nama_mk = mk["mata_kuliah"]
        hadir = mk["hadir"]
        sks = mk["sks"]
        print("    Mata Kuliah:", nama_mk)
        print("    Sks:", sks)
        print("    Kehadiran:", hadir)

        tugas = mk["nilai"]["tugas"]
        uts = mk["nilai"]["uts"]
        uas = mk["nilai"]["uas"]
        print("    Nilai:")
        print("        tugas:", tugas)
        print("        UTS:", uts)
        print("        UAS:", uas)
    print("-----------------------------")
# Out:
# nim: 2046363636
# nama: Iwan
# ..............................
#     Mata Kuliah: kecerdasan buatan
#     Sks: 3
#     Kehadiran: 18
#     Nilai:
#         tugas: 75
#         UTS: 80
#         UAS: 77
# ..............................
#     Mata Kuliah: basis data 1
#     Sks: 3
#     Kehadiran: 20
#     Nilai:
#         tugas: 80
#         UTS: 82
#         UAS: 67
# ..............................
#     Mata Kuliah: digital enterpreneur
#     Sks: 2
#     Kehadiran: 14
#     Nilai:
#         tugas: 90
#         UTS: 82
#         UAS: 80
# -----------------------------
# nim: 2046363777
# nama: Saepulloh
# ..............................
#     Mata Kuliah: algoritma & pemrogaman 1
#     Sks: 3
#     Kehadiran: 20
#     Nilai:
#         tugas: 90
#         UTS: 80
#         UAS: 70
# ..............................
#     Mata Kuliah: kalkulus 1
#     Sks: 3
#     Kehadiran: 21
#     Nilai:
#         tugas: 70
#         UTS: 60
#         UAS: 67
# ..............................
#     Mata Kuliah: statistika dan probabilitas
#     Sks: 2
#     Kehadiran: 13
#     Nilai:
#         tugas: 90
#         UTS: 70
#         UAS: 88
# -----------------------------
# nim: 2046363790
# nama: Sholihin
# ..............................
#     Mata Kuliah: Sistem Penunjang Keputusan
#     Sks: 3
#     Kehadiran: 19
#     Nilai:
#         tugas: 80
#         UTS: 90
#         UAS: 65
# ..............................
#     Mata Kuliah: Rekayasa Perangkat Lunak
#     Sks: 3
#     Kehadiran: 21
#     Nilai:
#         tugas: 70
#         UTS: 80
#         UAS: 77
# ..............................
#     Mata Kuliah: Etika Profesi
#     Sks: 2
#     Kehadiran: 14
#     Nilai:
#         tugas: 90
#         UTS: 80
#         UAS: 88
# -----------------------------

# %%
weight = {"hadir": 10, "tugas": 20, "uts":30, "uas":40}

def calculate(sks, hadir, tugas, uts, uas, bobot=weight):
    
    max_hadir = 0
    if sks == 2: 
        max_hadir = 14
    if sks == 3: 
        max_hadir = 21

    if not max_hadir:
        return None, "SKS tidak valid"
    hadir = hadir/max_hadir * bobot["hadir"]
    tugas = tugas/100 * bobot["tugas"]
    uts = uts/100 * bobot["uts"]
    uas = uas/100 * bobot["uas"]
    nilai = hadir + tugas + uts + uas
    return round(nilai,2), None

# %%
tugas = 100
uts = 70
uas =70
hadir = 14
sks = 3

nilai, _err = calculate(sks, hadir,  tugas, uts, uas)
print(nilai, _err)

nilai, _err = calculate(tugas=tugas, hadir=hadir, sks=sks, uas=uas, uts=uts)
print(nilai, _err)
# Out:
# 75.67 None
# 75.67 None

# %%
# Bobot nilai
weight = {"hadir": 10, "tugas": 20, "uts": 30, "uas": 40}

# Fungsi untuk menghitung nilai akhir
def calculate(sks, hadir, tugas, uts, uas, bobot=weight):
    max_hadir = 0
    if sks == 2:
        max_hadir = 14
    if sks == 3:
        max_hadir = 21

    if not max_hadir:
        return None, "SKS tidak valid"
    
    hadir = hadir / max_hadir * bobot["hadir"]
    tugas = tugas / 100 * bobot["tugas"]
    uts = uts / 100 * bobot["uts"]
    uas = uas / 100 * bobot["uas"]
    
    nilai = hadir + tugas + uts + uas
    return round(nilai, 2), None

def tentukan_grade(nilai_akhir):
    if nilai_akhir >= 85:
        return 'A'
    elif 70 <= nilai_akhir < 85:
        return 'B'
    elif 60 <= nilai_akhir < 70:
        return 'C'
    elif 50 <= nilai_akhir < 60:
        return 'D'
    else:
        return 'E'

def proses_data_mahasiswa(students):
    hasil_akhir = []
    
    for student in students:
        data_mahasiswa = {
            "nim": student['nim'],
            "nama": student['nama'],
            "semester": student['semester'],
            "rangkuman_nilai": []
        }
        
        for hasil in student['hasil']:
            nilai_akhir = hitung_nilai_akhir(hasil['nilai'])
            grade = tentukan_grade(nilai_akhir)
            
            rangkuman = {
                "mata_kuliah": hasil['mata_kuliah'],
                "sks": hasil['sks'],
                "hadir": hasil['hadir'],
                "nilai_akhir": nilai_akhir,
                "Grade": grade
            }
            
            data_mahasiswa['rangkuman_nilai'].append(rangkuman)
        
        hasil_akhir.append(data_mahasiswa)
    
    return hasil_akhir

# Memproses data
hasil_perhitungan = proses_data_mahasiswa(students)

# Menampilkan hasil
for mahasiswa in hasil_perhitungan:
    print(f"Nama: {mahasiswa['nama']}")
    print(f"NIM: {mahasiswa['nim']},")
    print(f"Semester: {mahasiswa['semester']}")
    for rangkuman in mahasiswa['rangkuman_nilai']:
        print(f"  Mata Kuliah: {rangkuman['mata_kuliah']}")
        print(f"     SKS: {rangkuman['sks']}")
        print(f"     Hadir: {rangkuman['hadir']}")
        print(f"     Nilai Akhir: {rangkuman['nilai_akhir']}")
        print(f"     Grade: {rangkuman['Grade']}")
    print("\n")
# Out:
# Nama: Iwan
# NIM: 2046363636,
# Semester: 6
#   Mata Kuliah: kecerdasan buatan
#      SKS: 3
#      Hadir: 18
#      Nilai Akhir: 77.3
#      Grade: B
#   Mata Kuliah: basis data 1
#      SKS: 3
#      Hadir: 20
#      Nilai Akhir: 75.4
#      Grade: B
#   Mata Kuliah: digital enterpreneur
#      SKS: 2
#      Hadir: 14
#      Nilai Akhir: 83.6
#      Grade: B
#
#
# Nama: Saepulloh
# NIM: 2046363777,
# Semester: 2
#   Mata Kuliah: algoritma & pemrogaman 1
#      SKS: 3
#      Hadir: 20
#      Nilai Akhir: 79.0
#      Grade: B
#   Mata Kuliah: kalkulus 1
#      SKS: 3
#      Hadir: 21
#      Nilai Akhir: 65.8
#      Grade: C
#   Mata Kuliah: statistika dan probabilitas
#      SKS: 2
#      Hadir: 13
#      Nilai Akhir: 83.2
#      Grade: B
#
#
# Nama: Sholihin
# NIM: 2046363790,
# Semester: 8
#   Mata Kuliah: Sistem Penunjang Keputusan
#      SKS: 3
#      Hadir: 19
#      Nilai Akhir: 77.0
#      Grade: B
#   Mata Kuliah: Rekayasa Perangkat Lunak
#      SKS: 3
#      Hadir: 21
#      Nilai Akhir: 75.8
#      Grade: B
#   Mata Kuliah: Etika Profesi
#      SKS: 2
#      Hadir: 14
#      Nilai Akhir: 86.2
#      Grade: A
